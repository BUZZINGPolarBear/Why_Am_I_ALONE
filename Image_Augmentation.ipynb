# %%
import random
import numpy as np
import os
import cv2
import glob
from PIL import Image
import PIL.ImageOps

# %%
#다음 변수를 수정하여 새로 만들 이미지 갯수를 정합니다.
num_augmented_images = 50

# %%
file_path = 'custom_data\Wonbin_faces\\'
file_names = os.listdir(file_path)
total_origin_image_num = len(file_names)
augment_cnt = 1

for i in range(1, num_augmented_images):
    change_picture_index = random.randrange(1, total_origin_image_num-1)
    print(change_picture_index)
    print(file_names[change_picture_index])
    file_name = file_names[change_picture_index]
    
    origin_image_path = 'custom_data\Wonbin_faces\\' + file_name
    print(origin_image_path)
    image = Image.open(origin_image_path)
    random_augment = random.randrange(1,4)
    
    if(random_augment == 1):
        #이미지 좌우 반전
        print("invert")
        inverted_image = image.transpose(Image.FLIP_LEFT_RIGHT)
        inverted_image.save(file_path + 'inverted_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 2):
        #이미지 기울이기
        print("rotate")
        rotated_image = image.rotate(random.randrange(-20, 20))
        rotated_image.save(file_path + 'rotated_' + str(augment_cnt) + '.png')
        
    elif(random_augment == 3):
        #노이즈 추가하기
        img = cv2.imread(origin_image_path)
        print("noise")
        row,col,ch= img.shape
        mean = 0
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col,ch))
        gauss = gauss.reshape(row,col,ch)
        noisy_array = img + gauss
        noisy_image = Image.fromarray(np.uint8(noisy_array)).convert('RGB')
        noisy_image.save(file_path + 'noiseAdded_' + str(augment_cnt) + '.png')
        
    augment_cnt += 1
# Out:
# 109
# wonbin_30.jpg
# custom_data\Wonbin_faces\wonbin_30.jpg
# invert
# 77
# rotated_42.png
# custom_data\Wonbin_faces\rotated_42.png
# noise
# 50
# noiseAdded_48.png
# custom_data\Wonbin_faces\noiseAdded_48.png
# noise
# 99
# wonbin_21.jpg
# custom_data\Wonbin_faces\wonbin_21.jpg
# invert
# 117
# wonbin_38.jpg
# custom_data\Wonbin_faces\wonbin_38.jpg
# noise
# 36
# noiseAdded_1.png
# custom_data\Wonbin_faces\noiseAdded_1.png
# rotate
# 56
# rotated_14.png
# custom_data\Wonbin_faces\rotated_14.png
# invert
# 34
# inverted_7.png
# custom_data\Wonbin_faces\inverted_7.png
# invert
# 38
# noiseAdded_18.png
# custom_data\Wonbin_faces\noiseAdded_18.png
# rotate
# 106
# wonbin_28.jpg
# custom_data\Wonbin_faces\wonbin_28.jpg
# rotate
# 65
# rotated_29.png
# custom_data\Wonbin_faces\rotated_29.png
# invert
# 24
# inverted_4.png
# custom_data\Wonbin_faces\inverted_4.png
# noise
# 36
# noiseAdded_1.png
# custom_data\Wonbin_faces\noiseAdded_1.png
# invert
# 126
# wonbin_46.jpg
# custom_data\Wonbin_faces\wonbin_46.jpg
# invert
# 95
# wonbin_18.jpg
# custom_data\Wonbin_faces\wonbin_18.jpg
# invert
# 1
# inverted_10.png
# custom_data\Wonbin_faces\inverted_10.png
# rotate
# 68
# rotated_33.png
# custom_data\Wonbin_faces\rotated_33.png
# rotate
# 117
# wonbin_38.jpg
# custom_data\Wonbin_faces\wonbin_38.jpg
# rotate
# 91
# wonbin_14.jpg
# custom_data\Wonbin_faces\wonbin_14.jpg
# noise
# 3
# inverted_12.png
# custom_data\Wonbin_faces\inverted_12.png
# noise
# 120
# wonbin_40.jpg
# custom_data\Wonbin_faces\wonbin_40.jpg
# invert
# 45
# noiseAdded_32.png
# custom_data\Wonbin_faces\noiseAdded_32.png
# noise
# 64
# rotated_24.png
# custom_data\Wonbin_faces\rotated_24.png
# rotate
# 12
# inverted_23.png
# custom_data\Wonbin_faces\inverted_23.png
# noise
# 122
# wonbin_42.jpg
# custom_data\Wonbin_faces\wonbin_42.jpg
# invert
# 97
# wonbin_2.jpg
# custom_data\Wonbin_faces\wonbin_2.jpg
# invert
# 97
# wonbin_2.jpg
# custom_data\Wonbin_faces\wonbin_2.jpg
# invert
# 42
# noiseAdded_25.png
# custom_data\Wonbin_faces\noiseAdded_25.png
# invert
# 1
# inverted_10.png
# custom_data\Wonbin_faces\inverted_10.png
# invert
# 41
# noiseAdded_22.png
# custom_data\Wonbin_faces\noiseAdded_22.png
# rotate
# 108
# wonbin_3.jpg
# custom_data\Wonbin_faces\wonbin_3.jpg
# invert
# 94
# wonbin_17.jpg
# custom_data\Wonbin_faces\wonbin_17.jpg
# rotate
# 52
# rotated_1.png
# custom_data\Wonbin_faces\rotated_1.png
# noise
# 113
# wonbin_34.jpg
# custom_data\Wonbin_faces\wonbin_34.jpg
# invert
# 100
# wonbin_22.jpg
# custom_data\Wonbin_faces\wonbin_22.jpg
# noise
# 35
# inverted_8.png
# custom_data\Wonbin_faces\inverted_8.png
# noise
# 50
# noiseAdded_48.png
# custom_data\Wonbin_faces\noiseAdded_48.png
# rotate
# 38
# noiseAdded_18.png
# custom_data\Wonbin_faces\noiseAdded_18.png
# rotate
# 102
# wonbin_24.jpg
# custom_data\Wonbin_faces\wonbin_24.jpg
# rotate
# 39
# noiseAdded_2.png
# custom_data\Wonbin_faces\noiseAdded_2.png
# noise
# 68
# rotated_33.png
# custom_data\Wonbin_faces\rotated_33.png
# invert
# 90
# wonbin_13.jpg
# custom_data\Wonbin_faces\wonbin_13.jpg
# invert
# 113
# wonbin_34.jpg
# custom_data\Wonbin_faces\wonbin_34.jpg
# noise
# 51
# noiseAdded_9.png
# custom_data\Wonbin_faces\noiseAdded_9.png
# invert
# 70
# rotated_35.png
# custom_data\Wonbin_faces\rotated_35.png
# invert
# 84
# rotated_8.png
# custom_data\Wonbin_faces\rotated_8.png
# noise
# 84
# rotated_8.png
# custom_data\Wonbin_faces\rotated_8.png
# rotate
# 94
# wonbin_17.jpg
# custom_data\Wonbin_faces\wonbin_17.jpg
# noise
# 120
# wonbin_40.jpg
# custom_data\Wonbin_faces\wonbin_40.jpg
# invert
